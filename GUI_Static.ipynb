# %% [markdown]
# # GUI

# %%
def inferensiFuzzy():
    def get_super(x):
        normal = "ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789+-=()"
        super_s = "ᴬᴮᶜᴰᴱᶠᴳᴴᴵᴶᴷᴸᴹᴺᴼᴾQᴿˢᵀᵁⱽᵂˣʸᶻᵃᵇᶜᵈᵉᶠᵍʰᶦʲᵏˡᵐⁿᵒᵖ۹ʳˢᵗᵘᵛʷˣʸᶻ⁰¹²³⁴⁵⁶⁷⁸⁹⁺⁻⁼⁽⁾"
        res = x.maketrans(''.join(normal), ''.join(super_s))
        return x.translate(res)
    derajat = get_super('o')

    def Grafik_Suhu_Luar_Ruangan(xdingin,ydingin,xsejuk,ysejuk,xnormal,ynormal,xhangat,yhangat,xpanas,ypanas):
        plt.title("Membership Function")
        plt.xlabel("Suhu Luar Ruangan")
        plt.ylabel("Derajat Keanggotaan")
        plt.plot(xdingin,ydingin,label='Dingin')
        plt.plot(xsejuk,ysejuk,label='Sejuk')
        plt.plot(xnormal,ynormal,label='Normal')
        plt.plot(xhangat,yhangat,label='Hangat')
        plt.plot(xpanas,ypanas,label='Panas')
        plt.legend(bbox_to_anchor = (1.0, 1), loc = 'upper left')
        plt.show()

    def Grafik_Suhu_Dalam_Ruangan(xsejuk,ysejuk,xnormal,ynormal,xhangat,yhangat):
        plt.title("Membership Function")
        plt.xlabel("Suhu Dalam Ruangan")
        plt.ylabel("Derajat Keanggotaan")
        plt.plot(xsejuk,ysejuk,label='Sejuk')
        plt.plot(xnormal,ynormal,label='Normal')
        plt.plot(xhangat,yhangat,label='Hangat')
        plt.legend(bbox_to_anchor = (1.0, 1), loc = 'upper left')
        plt.show()

    def Grafik_Banyak_Orang_Dalam_Ruangan(xsedikit,ysedikit,xsedang,ysedang,xbanyak,ybanyak):
        plt.title("Membership Function")
        plt.xlabel("Banyak Orang Dalam Ruangan")
        plt.ylabel("Derajat Keanggotaan")
        plt.plot(xsedikit,ysedikit,label='Sedikit')
        plt.plot(xsedang,ysedang,label='Sedang')
        plt.plot(xbanyak,ybanyak,label='Banyak')
        plt.legend(bbox_to_anchor = (1.0, 1), loc = 'upper left')
        plt.show()

    def Grafik_Suhu_Optimal_AC(xdingin,ydingin,xcukupd,ycukupd,xsejuk,ysejuk,xcukups,ycukups,xnormal,ynormal):
        plt.title("Membership Function")
        plt.xlabel("Suhu Optimal AC")
        plt.ylabel("Derajat Keanggotaan")
        plt.plot(xdingin,ydingin,label='Dingin')
        plt.plot(xcukupd,ycukupd,label='Cukup Dingin')
        plt.plot(xsejuk,ysejuk,label='Sejuk')
        plt.plot(xcukups,ycukups,label='Cukup Sejuk')
        plt.plot(xnormal,ynormal,label='Normal')
        plt.legend(bbox_to_anchor = (1.0, 1), loc = 'upper left')
        plt.show()

    def unique(list1):
        unique_list = []
        for x in list1:
            if x not in unique_list:
                unique_list.append(x)
        return unique_list
    
    y1a = [1,1,0]
    y2a = [0,1,0]
    y3a = [0,1,1]

    x1Dingin = [0,20,25]
    x1Sejuk = [20,25,30]
    x1Normal = [25,30,35]
    x1Hangat = [30,35,40]
    x1Panas = [35,40,50]

    y1b = [1,1,0]
    y2b = [0,1,0]
    y3b = [0,1,1]

    x2Sejuk = [0,20,30]
    x2Normal = [20,30,40]
    x2Hangat = [30,40,50]

    y1c = [1,1,0]
    y2c = [0,1,0]
    y3c = [0,1,1]

    x3Sedikit = [0,20,35]
    x3Sedang = [20,35,50]
    x3Banyak = [35,50,60]

    y1d = [1,1,0]
    y2d = [0,1,0]
    y3d = [0,1,0]
    y4d = [0,1,0]
    y5d = [0,1,1]

    x4Dingin = [15,18,21]
    x4CukupD = [18,21,24]
    x4Sejuk = [21,24,27]
    x4CukupS = [24,27,30]
    x4Normal = [27,30,33]
    
    slr = int(slr_scale.get())
    sdr = int(sdr_scale.get())
    bodr = int(bodr_scale.get())
    
    him_input_slr = []
    if 0<=slr<=25:
        him_input_slr.append("dingin")
    if 20<=slr<=30:
        him_input_slr.append("sejuk")
    if 25<=slr<=35:
        him_input_slr.append("normal")
    if 30<=slr<=40:
        him_input_slr.append("hangat")
    if 35<=slr<=50:
        him_input_slr.append("panas")          

    him_input_sdr = []
    if 0<=sdr<=30:
        him_input_sdr.append("sejuk")
    if 20<=sdr<=40:
        him_input_sdr.append("normal")
    if 30<=sdr<=50:
        him_input_sdr.append("hangat")

    him_input_bodr = []
    if 0<=bodr<=35:
        him_input_bodr.append("sedikit")
    if 20<=bodr<=50:
        him_input_bodr.append("sedang")
    if 35<=bodr<=60:
        him_input_bodr.append("banyak")
        
    him_y_slr = []
    if any("dingin" in s for s in him_input_slr):
        y1Dingin = max(min(1,(x1Dingin[2]-slr)/(x1Dingin[2]-x1Dingin[1])),0)
        him_y_slr.append(y1Dingin)
    if any("sejuk" in s for s in him_input_slr):
        y1Sejuk = max(min((slr-x1Sejuk[0])/(x1Sejuk[1]-x1Sejuk[0]),(x1Sejuk[2]-slr)/(x1Sejuk[2]-x1Sejuk[1])),0)
        him_y_slr.append(y1Sejuk)
    if any("normal" in s for s in him_input_slr):
        y1Normal = max(min((slr-x1Normal[0])/(x1Normal[1]-x1Normal[0]),(x1Normal[2]-slr)/(x1Normal[2]-x1Normal[1])),0)
        him_y_slr.append(y1Normal)
    if any("hangat" in s for s in him_input_slr):
        y1Hangat = max(min((slr-x1Hangat[0])/(x1Hangat[1]-x1Hangat[0]),(x1Hangat[2]-slr)/(x1Hangat[2]-x1Hangat[1])),0)
        him_y_slr.append(y1Hangat)
    if any("panas" in s for s in him_input_slr):
        y1Panas = max(min((slr-x1Panas[0])/(x1Panas[1]-x1Panas[0]),1),0)
        him_y_slr.append(y1Panas)

    him_y_sdr = []   
    if any("sejuk" in s for s in him_input_sdr):
        y2Sejuk = max(min(1,(x2Sejuk[2]-sdr)/(x2Sejuk[2]-x2Sejuk[1])),0)
        him_y_sdr.append(y2Sejuk)
    if any("normal" in s for s in him_input_sdr):
        y2Normal = max(min((sdr-x2Normal[0])/(x2Normal[1]-x2Normal[0]),(x2Normal[2]-sdr)/(x2Normal[2]-x2Normal[1])),0)
        him_y_sdr.append(y2Normal)
    if any("hangat" in s for s in him_input_sdr):
        y2Hangat = max(min((sdr-x2Hangat[0])/(x2Hangat[1]-x2Hangat[0]),1),0)
        him_y_sdr.append(y2Hangat)

    him_y_bodr = []  
    if any("sedikit" in s for s in him_input_bodr):
        y3Sedikit = max(min(1,(x3Sedikit[2]-bodr)/(x3Sedikit[2]-x3Sedikit[1])),0)
        him_y_bodr.append(y3Sedikit)
    if any("sedang" in s for s in him_input_bodr):
        y3Sedang = max(min((bodr-x3Sedang[0])/(x3Sedang[1]-x3Sedang[0]),(x3Sedang[2]-bodr)/(x3Sedang[2]-x3Sedang[1])),0)
        him_y_bodr.append(y3Sedang)
    if any("banyak" in s for s in him_input_bodr):
        y3Banyak = max(min((bodr-x3Banyak[0])/(x3Banyak[1]-x3Banyak[0]),1),0)
        him_y_bodr.append(y3Banyak)
    
    him_output_soa = [] # suhu optimal ac
    if any("dingin" in s for s in him_input_slr):
        if any("sejuk" in t for t in him_input_sdr):
            if any("sedikit" in u for u in him_input_bodr):
                him_output_soa.append("normal")
            if any("sedang" in u for u in him_input_bodr):
                him_output_soa.append("normal")
            if any("banyak" in u for u in him_input_bodr):
                him_output_soa.append("cukupsejuk")
        if any("normal" in t for t in him_input_sdr):
            if any("sedikit" in u for u in him_input_bodr):
                him_output_soa.append("cukupsejuk")
            if any("sedang" in u for u in him_input_bodr):
                him_output_soa.append("cukupsejuk")
            if any("banyak" in u for u in him_input_bodr):
                him_output_soa.append("sejuk")
        if any("hangat" in t for t in him_input_sdr):
            if any("sedikit" in u for u in him_input_bodr):
                him_output_soa.append("sejuk")
            if any("sedang" in u for u in him_input_bodr):
                him_output_soa.append("sejuk")
            if any("banyak" in u for u in him_input_bodr):
                him_output_soa.append("cukupsejuk")
    if any("sejuk" in s for s in him_input_slr):
        if any("sejuk" in t for t in him_input_sdr):
            if any("sedikit" in u for u in him_input_bodr):
                him_output_soa.append("cukupsejuk")
            if any("sedang" in u for u in him_input_bodr):
                him_output_soa.append("cukupsejuk")
            if any("banyak" in u for u in him_input_bodr):
                him_output_soa.append("sejuk")
        if any("normal" in t for t in him_input_sdr):
            if any("sedikit" in u for u in him_input_bodr):
                him_output_soa.append("sejuk")
            if any("sedang" in u for u in him_input_bodr):
                him_output_soa.append("sejuk")
            if any("banyak" in u for u in him_input_bodr):
                him_output_soa.append("cukupdingin")
        if any("hangat" in t for t in him_input_sdr):
            if any("sedikit" in u for u in him_input_bodr):
                him_output_soa.append("cukupdingin")
            if any("sedang" in u for u in him_input_bodr):
                him_output_soa.append("cukupdingin")
            if any("banyak" in u for u in him_input_bodr):
                him_output_soa.append("dingin")
    if any("normal" in s for s in him_input_slr):
        if any("sejuk" in t for t in him_input_sdr):
            if any("sedikit" in u for u in him_input_bodr):
                him_output_soa.append("cukupsejuk")
            if any("sedang" in u for u in him_input_bodr):
                him_output_soa.append("cukupsejuk")
            if any("banyak" in u for u in him_input_bodr):
                him_output_soa.append("sejuk")
        if any("normal" in t for t in him_input_sdr):
            if any("sedikit" in u for u in him_input_bodr):
                him_output_soa.append("sejuk")
            if any("sedang" in u for u in him_input_bodr):
                him_output_soa.append("sejuk")
            if any("banyak" in u for u in him_input_bodr):
                him_output_soa.append("cukupdingin")
        if any("hangat" in t for t in him_input_sdr):
            if any("sedikit" in u for u in him_input_bodr):
                him_output_soa.append("cukupdingin")
            if any("sedang" in u for u in him_input_bodr):
                him_output_soa.append("cukupdingin")
            if any("banyak" in u for u in him_input_bodr):
                him_output_soa.append("dingin")
    if any("hangat" in s for s in him_input_slr):
        if any("sejuk" in t for t in him_input_sdr):
            if any("sedikit" in u for u in him_input_bodr):
                him_output_soa.append("cukupsejuk")
            if any("sedang" in u for u in him_input_bodr):
                him_output_soa.append("cukupsejuk")
            if any("banyak" in u for u in him_input_bodr):
                him_output_soa.append("sejuk")
        if any("normal" in t for t in him_input_sdr):
            if any("sedikit" in u for u in him_input_bodr):
                him_output_soa.append("sejuk")
            if any("sedang" in u for u in him_input_bodr):
                him_output_soa.append("sejuk")
            if any("banyak" in u for u in him_input_bodr):
                him_output_soa.append("cukupdingin")
        if any("hangat" in t for t in him_input_sdr):
            if any("sedikit" in u for u in him_input_bodr):
                him_output_soa.append("cukupdingin")
            if any("sedang" in u for u in him_input_bodr):
                him_output_soa.append("cukupdingin")
            if any("banyak" in u for u in him_input_bodr):
                him_output_soa.append("dingin")
    if any("panas" in s for s in him_input_slr):
        if any("sejuk" in t for t in him_input_sdr):
            if any("sedikit" in u for u in him_input_bodr):
                him_output_soa.append("sejuk")
            if any("sedang" in u for u in him_input_bodr):
                him_output_soa.append("sejuk")
            if any("banyak" in u for u in him_input_bodr):
                him_output_soa.append("cukupdingin")
        if any("normal" in t for t in him_input_sdr):
            if any("sedikit" in u for u in him_input_bodr):
                him_output_soa.append("cukupdingin")
            if any("sedang" in u for u in him_input_bodr):
                him_output_soa.append("cukupdingin")
            if any("banyak" in u for u in him_input_bodr):
                him_output_soa.append("dingin")
        if any("hangat" in t for t in him_input_sdr):
            if any("sedikit" in u for u in him_input_bodr):
                him_output_soa.append("dingin")
            if any("sedang" in u for u in him_input_bodr):
                him_output_soa.append("dingin")
            if any("banyak" in u for u in him_input_bodr):
                him_output_soa.append("dingin")
                
    him_y_soa = []
    for i in him_y_slr:
        for j in him_y_sdr:
            for k in him_y_bodr:
                him_y_soa.append(min(i,j,k))
    
    him_output_soa_set = unique(him_output_soa)
    him_y_soa_set = []
    for i in him_output_soa_set:
        him_y_soa_set_temp = []
        for j,k in zip(him_output_soa,him_y_soa):
            if i == j:
                him_y_soa_set_temp.append(k)
        him_y_soa_set.append(max(him_y_soa_set_temp))
        
    him_x_soa_set = []
    for i in him_output_soa_set:
        if i == "dingin":
            him_x_soa_set.append(x4Dingin[1])
        if i == "cukupdingin":
            him_x_soa_set.append(x4CukupD[1])
        if i == "sejuk":
            him_x_soa_set.append(x4Sejuk[1])
        if i == "cukupsejuk":
            him_x_soa_set.append(x4CukupS[1])
        if i == "normal":
            him_x_soa_set.append(x4Normal[1])
    
    sigmaDKsoa = 0
    sigmaDK = 0
    for i,j in zip(him_y_soa_set,him_x_soa_set):
        sigmaDK += i
        sigmaDKsoa += (i*j)
    y_defuzz = sigmaDKsoa/sigmaDK
    
    soa_output.config(text=f'{round(y_defuzz)} {derajat}C')

# %%
import matplotlib.pyplot as plt
from tkinter import *
root = Tk()
root.title("Suhu Optimal AC")

label1 = Label(root, text="Input Suhu Luar Ruangan")
label2 = Label(root, text="Input Suhu Dalam Ruangan")
label3 = Label(root, text="Input Banyak Orang Dalam Ruangan")
label4 = Label(root, text="Suhu Optimal AC")
slr_scale = Scale(root, from_=0, to=50, orient=HORIZONTAL)
sdr_scale = Scale(root, from_=0, to=50, orient=HORIZONTAL)
bodr_scale = Scale(root, from_=0, to=60, orient=HORIZONTAL)
soa_output = Label(root, text="SUHU", font=("Arial", 25), width = 30, borderwidth=5)
myButton = Button(root, text="Hasil", width=30, height=2, command=inferensiFuzzy)

label1.grid(row=1, column=1)
label2.grid(row=1, column=2)
label3.grid(row=1, column=3)
label4.grid(row=4, column=2)
slr_scale.grid(row=2, column=1, padx=30, pady=5)
sdr_scale.grid(row=2, column=2, padx=30, pady=5)
bodr_scale.grid(row=2, column=3, padx=30, pady=5)
soa_output.grid(row=5, column=2, padx=30, pady=5)
myButton.grid(row=3, column=1, columnspan=3, pady=10)

root.mainloop()

# %% [markdown]
# ![Screenshot%202022-12-31%20125447.jpg](attachment:Screenshot%202022-12-31%20125447.jpg)
